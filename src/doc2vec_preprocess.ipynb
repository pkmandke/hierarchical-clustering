# %%
! python3 --version
# Out:
# Python 3.7.4

# %%
! ls ../thesis/thesis/
# Out:
# 10000  10009  10019  10029  10039  10049  10060  10069	10078  10090
# 10001  10010  10020  10030  10040  10050  10061  10070	10079  10092
# 10002  10012  10021  10031  10041  10051  10062  10071	10080  10093
# 10003  10013  10022  10032  10042  10053  10063  10072	10082  10094
# 10004  10014  10023  10033  10043  10054  10064  10073	10083  10095
# 10005  10015  10025  10035  10044  10055  10065  10074	10085  10098
# 10006  10016  10026  10036  10046  10057  10066  10075	10087  10099
# 10007  10017  10027  10037  10047  10058  10067  10076	10088  10100
# 10008  10018  10028  10038  10048  10059  10068  10077	10089  10101

# %%
! pip3 install gensim
! pip3 install nltk
! pip3 install numpy
# Out:
# Collecting gensim
#   Downloading https://files.pythonhosted.org/packages/44/93/c6011037f24e3106d13f3be55297bf84ece2bf15b278cc4776339dc52db5/gensim-3.8.1-cp37-cp37m-manylinux1_x86_64.whl (24.2MB)
#      |████████████████████████████████| 24.2MB 29.2MB/s eta 0:00:01   |██▉                             | 2.2MB 1.4MB/s eta 0:00:16     |█████████████████▏              | 13.0MB 1.4MB/s eta 0:00:08     |█████████████████████████████▉  | 22.6MB 29.2MB/s eta 0:00:01
# Collecting scipy>=0.18.1 (from gensim)
#   Downloading https://files.pythonhosted.org/packages/13/69/d3819eae2af1811895e64b6277669906e861053b93000534a5809940f321/scipy-1.3.2-cp37-cp37m-manylinux1_x86_64.whl (25.2MB)
#      |████████████████████████████████| 25.2MB 1.2MB/s  eta 0:00:01    |▍                               | 348kB 19.9MB/s eta 0:00:02     |██████████                      | 7.8MB 19.9MB/s eta 0:00:01     |█████████████████▊              | 14.0MB 19.9MB/s eta 0:00:01
# Requirement already satisfied: six>=1.5.0 in /usr/local/lib/python3.7/site-packages (from gensim) (1.12.0)
# Collecting numpy>=1.11.3 (from gensim)
#   Downloading https://files.pythonhosted.org/packages/9b/af/4fc72f9d38e43b092e91e5b8cb9956d25b2e3ff8c75aed95df5569e4734e/numpy-1.17.4-cp37-cp37m-manylinux1_x86_64.whl (20.0MB)
#      |████████████████████████████████| 20.0MB 23.1MB/s eta 0:00:01B/s eta 0:00:01     |█████████████████████████▌      | 16.0MB 23.1MB/s eta 0:00:01
# Collecting smart-open>=1.8.1 (from gensim)
#   Downloading https://files.pythonhosted.org/packages/0c/09/735f2786dfac9bbf39d244ce75c0313d27d4962e71e0774750dc809f2395/smart_open-1.9.0.tar.gz (70kB)
#      |████████████████████████████████| 71kB 14.7MB/s eta 0:00:01
# Collecting boto>=2.32 (from smart-open>=1.8.1->gensim)
#   Downloading https://files.pythonhosted.org/packages/23/10/c0b78c27298029e4454a472a1919bde20cb182dab1662cec7f2ca1dcc523/boto-2.49.0-py2.py3-none-any.whl (1.4MB)
#      |████████████████████████████████| 1.4MB 14.4MB/s eta 0:00:01�████████▌                  | 573kB 14.4MB/s eta 0:00:01
# Collecting requests (from smart-open>=1.8.1->gensim)
#   Downloading https://files.pythonhosted.org/packages/51/bd/23c926cd341ea6b7dd0b2a00aba99ae0f828be89d72b2190f27c11d4b7fb/requests-2.22.0-py2.py3-none-any.whl (57kB)
#      |████████████████████████████████| 61kB 9.0MB/s  eta 0:00:01
# Collecting boto3 (from smart-open>=1.8.1->gensim)
#   Downloading https://files.pythonhosted.org/packages/3b/5c/3896c5c2f2eedaa4b60836f7e91d792328d59a09e3353db5016f49eaa51b/boto3-1.10.15-py2.py3-none-any.whl (128kB)
#      |████████████████████████████████| 133kB 28.0MB/s eta 0:00:01
# Collecting chardet<3.1.0,>=3.0.2 (from requests->smart-open>=1.8.1->gensim)
#   Downloading https://files.pythonhosted.org/packages/bc/a9/01ffebfb562e4274b6487b4bb1ddec7ca55ec7510b22e4c51f14098443b8/chardet-3.0.4-py2.py3-none-any.whl (133kB)
#      |████████████████████████████████| 143kB 14.6MB/s eta 0:00:01
# Collecting certifi>=2017.4.17 (from requests->smart-open>=1.8.1->gensim)
#   Downloading https://files.pythonhosted.org/packages/18/b0/8146a4f8dd402f60744fa380bc73ca47303cccf8b9190fd16a827281eac2/certifi-2019.9.11-py2.py3-none-any.whl (154kB)
#      |████████████████████████████████| 163kB 17.3MB/s eta 0:00:01
# Collecting urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 (from requests->smart-open>=1.8.1->gensim)
#   Downloading https://files.pythonhosted.org/packages/b4/40/a9837291310ee1ccc242ceb6ebfd9eb21539649f193a7c8c86ba15b98539/urllib3-1.25.7-py2.py3-none-any.whl (125kB)
#      |████████████████████████████████| 133kB 18.1MB/s eta 0:00:01
# Collecting idna<2.9,>=2.5 (from requests->smart-open>=1.8.1->gensim)
#   Downloading https://files.pythonhosted.org/packages/14/2c/cd551d81dbe15200be1cf41cd03869a46fe7226e7450af7a6545bfc474c9/idna-2.8-py2.py3-none-any.whl (58kB)
#      |████████████████████████████████| 61kB 9.1MB/s  eta 0:00:01
# Collecting s3transfer<0.3.0,>=0.2.0 (from boto3->smart-open>=1.8.1->gensim)
#   Downloading https://files.pythonhosted.org/packages/16/8a/1fc3dba0c4923c2a76e1ff0d52b305c44606da63f718d14d3231e21c51b0/s3transfer-0.2.1-py2.py3-none-any.whl (70kB)
#      |████████████████████████████████| 71kB 9.6MB/s  eta 0:00:01
# Collecting jmespath<1.0.0,>=0.7.1 (from boto3->smart-open>=1.8.1->gensim)
#   Downloading https://files.pythonhosted.org/packages/83/94/7179c3832a6d45b266ddb2aac329e101367fbdb11f425f13771d27f225bb/jmespath-0.9.4-py2.py3-none-any.whl
# Collecting botocore<1.14.0,>=1.13.15 (from boto3->smart-open>=1.8.1->gensim)
#   Downloading https://files.pythonhosted.org/packages/c1/f8/54a28c1900ca1498a02e7ba6e227be4a6db976e49bd0d374e541b09b5738/botocore-1.13.15-py2.py3-none-any.whl (5.4MB)
#      |████████████████████████████████| 5.4MB 24.0MB/s eta 0:00:01                      | 266kB 24.0MB/s eta 0:00:01
# Collecting docutils<0.16,>=0.10 (from botocore<1.14.0,>=1.13.15->boto3->smart-open>=1.8.1->gensim)
#   Downloading https://files.pythonhosted.org/packages/22/cd/a6aa959dca619918ccb55023b4cb151949c64d4d5d55b3f4ffd7eee0c6e8/docutils-0.15.2-py3-none-any.whl (547kB)
#      |████████████████████████████████| 552kB 23.1MB/s eta 0:00:01
# Requirement already satisfied: python-dateutil<2.8.1,>=2.1; python_version >= "2.7" in /usr/local/lib/python3.7/site-packages (from botocore<1.14.0,>=1.13.15->boto3->smart-open>=1.8.1->gensim) (2.8.0)
# Building wheels for collected packages: smart-open
#   Building wheel for smart-open (setup.py) ... done
#   Created wheel for smart-open: filename=smart_open-1.9.0-cp37-none-any.whl size=73088 sha256=a89d9b4fe9a1869358d1ccfaec5454375a073e273041d10f736c381dafecf880
#   Stored in directory: /root/.cache/pip/wheels/ab/10/93/5cff86f5b721d77edaecc29959b1c60d894be1f66d91407d28
# Successfully built smart-open
# Installing collected packages: numpy, scipy, boto, chardet, certifi, urllib3, idna, requests, docutils, jmespath, botocore, s3transfer, boto3, smart-open, gensim
# Successfully installed boto-2.49.0 boto3-1.10.15 botocore-1.13.15 certifi-2019.9.11 chardet-3.0.4 docutils-0.15.2 gensim-3.8.1 idna-2.8 jmespath-0.9.4 numpy-1.17.4 requests-2.22.0 s3transfer-0.2.1 scipy-1.3.2 smart-open-1.9.0 urllib3-1.25.7
# WARNING: You are using pip version 19.2.3, however version 19.3.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# Collecting nltk
#   Downloading https://files.pythonhosted.org/packages/f6/1d/d925cfb4f324ede997f6d47bea4d9babba51b49e87a767c170b77005889d/nltk-3.4.5.zip (1.5MB)
#      |████████████████████████████████| 1.5MB 1.3MB/s eta 0:00:01     |█████████████████████████       | 1.1MB 1.3MB/s eta 0:00:01
# Requirement already satisfied: six in /usr/local/lib/python3.7/site-packages (from nltk) (1.12.0)
# Building wheels for collected packages: nltk
#   Building wheel for nltk (setup.py) ... done
#   Created wheel for nltk: filename=nltk-3.4.5-cp37-none-any.whl size=1449907 sha256=96d6a934ff8fe7e19be056fb5daa59015559313f55f210da9626dac41db8f894
#   Stored in directory: /root/.cache/pip/wheels/96/86/f6/68ab24c23f207c0077381a5e3904b2815136b879538a24b483
# Successfully built nltk
# Installing collected packages: nltk
# Successfully installed nltk-3.4.5
# WARNING: You are using pip version 19.2.3, however version 19.3.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/site-packages (1.17.4)
# WARNING: You are using pip version 19.2.3, however version 19.3.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
import gensim
import os
import nltk

nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
N = 10000
#ETD_PATH = '/media/pkmandke/DATA/ECE/courses/info_ret/code/thesis/'
ETD_PATH = '../thesis/'
list_of_docs = os.listdir(ETD_PATH)
list_of_docs
# Out:
# ['10000',
#  '10001',
#  '10002',
#  '10003',
#  '10004',
#  '10005',
#  '10006',
#  '10007',
#  '10008',
#  '10009',
#  '10010',
#  '10012',
#  '10013',
#  '10014',
#  '10015',
#  '10016',
#  '10017',
#  '10018',
#  '10019',
#  '10020',
#  '10021',
#  '10022',
#  '10023',
#  '10025',
#  '10026',
#  '10027',
#  '10028',
#  '10029',
#  '10030',
#  '10031',
#  '10032',
#  '10033',
#  '10035',
#  '10036',
#  '10037',
#  '10038',
#  '10039',
#  '10040',
#  '10041',
#  '10172',
#  '10173',
#  '10174',
#  '10175',
#  '10176',
#  '10177',
#  '10178',
#  '10179',
#  '11128',
#  '11270',
#  '19190',
#  '19193',
#  '19200',
#  '19202',
#  '19207',
#  '19211',
#  '19213',
#  '19214',
#  '19217',
#  '19218',
#  '19221',
#  '19224',
#  '19226',
#  '19227',
#  '19229',
#  '19230',
#  '19231',
#  '19307',
#  '19309',
#  '19315',
#  '19317',
#  '19319',
#  '19321',
#  '19325',
#  '19329',
#  '19331',
#  '19337',
#  '19343',
#  '20373',
#  '20377',
#  '22015',
#  '22018',
#  '22019',
#  '22021',
#  '22031',
#  '22032',
#  '22033',
#  '22045',
#  '22048',
#  '22049',
#  '22051',
#  '22052',
#  '22053',
#  '22078',
#  '22079',
#  '22080',
#  '23078',
#  '23079',
#  '23080',
#  '23083',
#  '23084',
#  '23085',
#  '23086',
#  '23087',
#  '10093',
#  '10094',
#  '10095',
#  '10098',
#  '10099',
#  '10100',
#  '10101',
#  '10102',
#  '10103',
#  '10104',
#  '10105',
#  '10106',
#  '10108',
#  '10109',
#  '10110',
#  '10111',
#  '10112',
#  '10113',
#  '10114',
#  '10115',
#  '10117',
#  '10118',
#  '10119',
#  '10120',
#  '10121',
#  '10122',
#  '10123',
#  '10124',
#  '10125',
#  '10126',
#  '10127',
#  '10128',
#  '10129',
#  '10130',
#  '23089',
#  '23090',
#  '23091',
#  '23093',
#  '23094',
#  '23096',
#  '23097',
#  '23098',
#  '23099',
#  '23100',
#  '23101',
#  '23102',
#  '23103',
#  '23104',
#  '23105',
#  '23106',
#  '23107',
#  '23108',
#  '23109',
#  '23110',
#  '10042',
#  '10066',
#  '10092',
#  '10131',
#  '10171',
#  '19233',
#  '19303',
#  '23088',
#  '23111',
#  '10132',
#  '10134',
#  '10135',
#  '10136',
#  '10137',
#  '10138',
#  '10139',
#  '10140',
#  '10141',
#  '10142',
#  '10143',
#  '10144',
#  '10145',
#  '10146',
#  '10147',
#  '10148',
#  '10149',
#  '10150',
#  '10151',
#  '10153',
#  '10154',
#  '10155',
#  '10156',
#  '10157',
#  '10158',
#  '10159',
#  '10160',
#  '10161',
#  '10162',
#  '10163',
#  '10164',
#  '10165',
#  '10166',
#  '10167',
#  '10168',
#  '10169',
#  '10170',
#  '10043',
#  '10044',
#  '10046',
#  '10047',
#  '10048',
#  '10049',
#  '10050',
#  '10051',
#  '10053',
#  '10054',
#  '10055',
#  '10057',
#  '10058',
#  '10059',
#  '10060',
#  '10061',
#  '10062',
#  '10063',
#  '10064',
#  '10065',
#  '19235',
#  '19236',
#  '19238',
#  '19242',
#  '19245',
#  '19246',
#  '19247',
#  '19249',
#  '19250',
#  '19252',
#  '19254',
#  '19255',
#  '19257',
#  '19258',
#  '19261',
#  '19263',
#  '19264',
#  '19265',
#  '19267',
#  '19268',
#  '19269',
#  '19272',
#  '19275',
#  '19281',
#  '19282',
#  '19286',
#  '19287',
#  '19288',
#  '19293',
#  '19294',
#  '19298',
#  '19299',
#  '19300',
#  '19301',
#  '19302',
#  '10067',
#  '10068',
#  '10069',
#  '10070',
#  '10071',
#  '10072',
#  '10073',
#  '10074',
#  '10075',
#  '10076',
#  '10077',
#  '10078',
#  '10079',
#  '10080',
#  '10082',
#  '10083',
#  '10085',
#  '10087',
#  '10088',
#  '10089',
#  '10090',
#  '23112',
#  '23117',
#  '23118',
#  '23119',
#  '23120',
#  '23121',
#  '23122',
#  '23123',
#  '23124',
#  '23125',
#  '23126',
#  '23128',
#  '23130',
#  '23131',
#  '23132',
#  '23133',
#  '23134',
#  '23135',
#  '23136',
#  '23137',
#  '23139']

# %%
def data_generator():
    cnt = 0
    for idx, folder in enumerate(list_of_docs):
        for _ in os.listdir(ETD_PATH + folder):
            file_name = ''
            if _.endswith('.pdf.txt') or _.endswith('.PDF.txt'):
                file_name = _
                break
        if file_name:
            with open(ETD_PATH + folder + '/' + file_name) as f:
                document = f.read()

                tokens = gensim.utils.simple_preprocess(document)
                print(type(tokens))
                yield gensim.models.doc2vec.TaggedDocument(tokens, [idx])

# %%
train_corpus = list(data_generator())
# Out:
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-72-7226f6dfbf44> in <module>
# ----> 1 train_corpus = list(data_generator())
#
# <ipython-input-71-198ceefdefd9> in data_generator()
#      11                 document = f.read()
#      12
# ---> 13                 tokens = gensim.utils.simple_preprocess(document)
#      14                 print(type(tokens))
#      15                 yield gensim.models.doc2vec.TaggedDocument(tokens, [idx])
#
# ~/venv/hierarch_clus/lib/python3.6/site-packages/gensim/utils.py in simple_preprocess(doc, deacc, min_len, max_len)
#     303     """
#     304     tokens = [
# --> 305         token for token in tokenize(doc, lower=True, deacc=deacc, errors='ignore')
#     306         if min_len <= len(token) <= max_len and not token.startswith('_')
#     307     ]
#
# ~/venv/hierarch_clus/lib/python3.6/site-packages/gensim/utils.py in <listcomp>(.0)
#     303     """
#     304     tokens = [
# --> 305         token for token in tokenize(doc, lower=True, deacc=deacc, errors='ignore')
#     306         if min_len <= len(token) <= max_len and not token.startswith('_')
#     307     ]
#
# ~/venv/hierarch_clus/lib/python3.6/site-packages/gensim/utils.py in simple_tokenize(text)
#     276
#     277     """
# --> 278     for match in PAT_ALPHABETIC.finditer(text):
#     279         yield match.group()
#     280
#
# KeyboardInterrupt:

# %%
model = gensim.models.doc2vec.Doc2Vec(vector_size=128, min_count=2, epochs=20)
model.build_vocab(train_corpus)

# %%
model.train(train_corpus, total_examples=model.corpus_count, epochs=model.epochs)

# %%
from gensim.test.utils import get_tmpfile
fn = get_tmpfile('../obj/doc2vec1')
model.save('./mydoc2vec')

# %%
m1 = gensim.models.doc2vec.Doc2Vec.load('./mydoc2vec')
# Out:
# FileNotFoundErrorTraceback (most recent call last)
# <ipython-input-4-2906fd90bd6a> in <module>
# ----> 1 m1 = gensim.models.doc2vec.Doc2Vec.load('./mydoc2vec')
#
# /usr/local/lib/python3.7/site-packages/gensim/models/doc2vec.py in load(cls, *args, **kwargs)
#    1111         """
#    1112         try:
# -> 1113             return super(Doc2Vec, cls).load(*args, **kwargs)
#    1114         except AttributeError:
#    1115             logger.info('Model saved using code from earlier Gensim Version. Re-loading old model in a compatible way.')
#
# /usr/local/lib/python3.7/site-packages/gensim/models/base_any2vec.py in load(cls, *args, **kwargs)
#    1242
#    1243         """
# -> 1244         model = super(BaseWordEmbeddingsModel, cls).load(*args, **kwargs)
#    1245         if not hasattr(model, 'ns_exponent'):
#    1246             model.ns_exponent = 0.75
#
# /usr/local/lib/python3.7/site-packages/gensim/models/base_any2vec.py in load(cls, fname_or_handle, **kwargs)
#     601
#     602         """
# --> 603         return super(BaseAny2VecModel, cls).load(fname_or_handle, **kwargs)
#     604
#     605     def save(self, fname_or_handle, **kwargs):
#
# /usr/local/lib/python3.7/site-packages/gensim/utils.py in load(cls, fname, mmap)
#     424         compress, subname = SaveLoad._adapt_by_suffix(fname)
#     425
# --> 426         obj = unpickle(fname)
#     427         obj._load_specials(fname, mmap, compress, subname)
#     428         logger.info("loaded %s", fname)
#
# /usr/local/lib/python3.7/site-packages/gensim/utils.py in unpickle(fname)
#    1379
#    1380     """
# -> 1381     with open(fname, 'rb') as f:
#    1382         # Because of loading from S3 load can't be used (missing readline in smart_open)
#    1383         if sys.version_info > (3, 0):
#
# /usr/local/lib/python3.7/site-packages/smart_open/smart_open_lib.py in open(uri, mode, buffering, encoding, errors, newline, closefd, opener, ignore_ext, transport_params)
#     306         buffering=buffering,
#     307         encoding=encoding,
# --> 308         errors=errors,
#     309     )
#     310     if fobj is not None:
#
# /usr/local/lib/python3.7/site-packages/smart_open/smart_open_lib.py in _shortcut_open(uri, mode, ignore_ext, buffering, encoding, errors)
#     515     #
#     516     if six.PY3:
# --> 517         return _builtin_open(parsed_uri.uri_path, mode, buffering=buffering, **open_kwargs)
#     518     elif not open_kwargs:
#     519         return _builtin_open(parsed_uri.uri_path, mode, buffering=buffering)
#
# FileNotFoundError: [Errno 2] No such file or directory: './mydoc2vec'

# %%
m1.vocabulary.scan_vocab(documents=data_generator(), docvecs=m1.docvecs)
# Out:
# (5600043, 300)

# %%
ranks = []
second_ranks = []
for doc_id in range(len(train_corpus)):
    inferred_vector = m1.infer_vector(train_corpus[doc_id].words)
    sims = m1.docvecs.most_similar([inferred_vector], topn=len(m1.docvecs))
    rank = [docid for docid, sim in sims].index(doc_id)
    ranks.append(rank)

    second_ranks.append(sims[1])

# %%
import collections

counter = collections.Counter(ranks)
print(counter)
# Out:
# Counter({2079: 2, 13173: 2, 4274: 2, 20813: 2, 11922: 1, 17509: 1, 7563: 1, 6034: 1, 2148: 1, 9527: 1, 6764: 1, 16841: 1, 5734: 1, 342: 1, 878: 1, 22025: 1, 9930: 1, 2960: 1, 12911: 1, 17232: 1, 14280: 1, 5901: 1, 717: 1, 13052: 1, 11040: 1, 20780: 1, 19304: 1, 10453: 1, 17760: 1, 355: 1, 3389: 1, 20898: 1, 10489: 1, 8827: 1, 15214: 1, 4859: 1, 1400: 1, 14732: 1, 20534: 1, 23074: 1, 702: 1, 11249: 1, 12174: 1, 21620: 1, 1128: 1, 16778: 1, 1516: 1, 6573: 1, 19513: 1, 11577: 1, 6670: 1, 5603: 1, 7703: 1, 13532: 1, 6669: 1, 11015: 1, 16529: 1, 2194: 1, 18659: 1, 17805: 1, 10157: 1, 398: 1, 13474: 1, 8223: 1, 7342: 1, 10723: 1, 19388: 1, 20592: 1, 17497: 1, 16093: 1, 17970: 1, 20569: 1, 2657: 1, 18237: 1, 11780: 1, 9480: 1, 19553: 1, 4012: 1, 1752: 1, 11675: 1, 20110: 1, 20417: 1, 7277: 1, 858: 1, 13376: 1, 6816: 1, 16461: 1, 22213: 1, 12163: 1, 9640: 1, 16618: 1, 5920: 1, 7515: 1, 17553: 1, 6998: 1, 7212: 1, 3665: 1, 9193: 1, 18965: 1, 2360: 1, 6986: 1, 7138: 1, 16402: 1, 22083: 1, 10054: 1, 14406: 1, 19210: 1, 11748: 1, 9975: 1, 13130: 1, 18544: 1, 19468: 1, 8857: 1, 14061: 1, 18600: 1, 11141: 1, 21851: 1, 4953: 1, 12533: 1, 4726: 1, 1713: 1, 5987: 1, 15239: 1, 20449: 1, 3562: 1, 10273: 1, 8077: 1, 20947: 1, 13791: 1, 210: 1, 14483: 1, 1860: 1, 16616: 1, 15977: 1, 12644: 1, 18759: 1, 17902: 1, 9455: 1, 21828: 1, 18459: 1, 450: 1, 3212: 1, 20389: 1, 8671: 1, 17500: 1, 20391: 1, 709: 1, 16097: 1, 15173: 1, 7116: 1, 1242: 1, 7790: 1, 19419: 1, 4139: 1, 11701: 1, 19597: 1, 2648: 1, 12534: 1, 4085: 1, 6169: 1, 5741: 1, 12902: 1, 19666: 1, 22088: 1, 6924: 1, 4975: 1, 779: 1, 1569: 1, 7837: 1, 16384: 1, 9801: 1, 11775: 1, 2429: 1, 7233: 1, 3974: 1, 3017: 1, 20888: 1, 1694: 1, 11089: 1, 22879: 1, 5619: 1, 6982: 1, 13449: 1, 16942: 1, 8655: 1, 21613: 1, 13090: 1, 17106: 1, 8702: 1, 3641: 1, 19148: 1, 5704: 1, 9803: 1, 11939: 1, 4982: 1, 14236: 1, 21037: 1, 19768: 1, 6808: 1, 18184: 1, 11103: 1, 4849: 1, 17093: 1, 14579: 1, 19294: 1, 6521: 1, 21235: 1, 14945: 1, 7467: 1, 13083: 1, 8092: 1, 11772: 1, 4603: 1, 21667: 1, 504: 1, 15827: 1, 5419: 1, 9917: 1, 18540: 1, 7269: 1, 22485: 1, 9559: 1, 4306: 1, 11316: 1, 8232: 1, 22308: 1, 7969: 1, 528: 1, 708: 1, 19063: 1, 12346: 1, 2664: 1, 4108: 1, 13334: 1, 22695: 1, 10985: 1, 16390: 1, 11779: 1, 11431: 1, 11407: 1, 11935: 1, 21404: 1, 5441: 1, 12483: 1, 14713: 1, 16467: 1, 2586: 1, 20489: 1, 19853: 1, 21586: 1, 1921: 1, 7004: 1, 20369: 1, 20166: 1, 11093: 1, 10416: 1, 6519: 1, 6278: 1, 19799: 1, 19354: 1, 8147: 1, 8747: 1, 22300: 1, 3520: 1, 11265: 1, 12439: 1, 12701: 1, 4441: 1, 2699: 1, 15382: 1, 21564: 1, 6324: 1, 20435: 1, 5510: 1, 8700: 1, 10078: 1, 18823: 1, 2336: 1, 5184: 1, 19099: 1, 18709: 1, 18811: 1, 10059: 1, 12647: 1, 20730: 1, 14539: 1, 9012: 1, 13672: 1, 13136: 1, 20303: 1, 3840: 1, 21180: 1, 22908: 1, 20140: 1, 13961: 1, 7341: 1})

# %%
m1.docvecs[1]
# Out:
# array([-6.792167 , -4.190204 ,  3.4028997,  1.4658272,  2.6295373,
#        -6.4474425, -1.9747512,  8.188361 ,  1.4898632, -6.621423 ,
#        -1.0630257,  8.689304 ,  1.5611778,  2.560917 , -2.6793582,
#        -4.301983 , -4.4781256,  1.7389203, -9.450199 , -7.642398 ],
#       dtype=float32)

# %%
train_corpus[0].words
# Out:
# ['stochastic',
#  'petri',
#  'net',
#  'models',
#  'of',
#  'service',
#  'availability',
#  'in',
#  'pbnm',
#  'system',
#  'for',
#  'mobile',
#  'ad',
#  'hoc',
#  'networks',
#  'aniket',
#  'bhat',
#  'thesis',
#  'submitted',
#  'to',
#  'the',
#  'faculty',
#  'of',
#  'the',
#  'virginia',
#  'polytechnic',
#  'institute',
#  'and',
#  'state',
#  'university',
#  'in',
#  'partial',
#  'fulfillment',
#  'of',
#  'the',
#  'requirements',
#  'for',
#  'the',
#  'degree',
#  'of',
#  'master',
#  'of',
#  'science',
#  'in',
#  'computer',
#  'engineering',
#  'committee',
#  'dr',
#  'luiz',
#  'dasilva',
#  'committee',
#  'chair',
#  'dr',
#  'scott',
#  'midkiff',
#  'committee',
#  'member',
#  'dr',
#  'kaustubh',
#  'phanse',
#  'committee',
#  'member',
#  'dr',
#  'srinidhi',
#  'varadarajan',
#  'committee',
#  'member',
#  'july',
#  'blacksburg',
#  'virginia',
#  'keywords',
#  'service',
#  'availability',
#  'policy',
#  'based',
#  'network',
#  'management',
#  'mobile',
#  'ad',
#  'hoc',
#  'networks',
#  'non',
#  'markovian',
#  'modeling',
#  'stochastic',
#  'petri',
#  'nets',
#  'copyright',
#  'aniket',
#  'bhat',
#  'stochastic',
#  'petri',
#  'net',
#  'models',
#  'of',
#  'service',
#  'availability',
#  'in',
#  'pbnm',
#  'system',
#  'for',
#  'mobile',
#  'ad',
#  'hoc',
#  'networks',
#  'aniket',
#  'bhat',
#  'abstract',
#  'policy',
#  'based',
#  'network',
#  'management',
#  'is',
#  'promising',
#  'approach',
#  'for',
#  'provisioning',
#  'and',
#  'management',
#  'of',
#  'quality',
#  'of',
#  'service',
#  'in',
#  'mobile',
#  'ad',
#  'hoc',
#  'networks',
#  'in',
#  'this',
#  'thesis',
#  'we',
#  'focus',
#  'on',
#  'performance',
#  'evaluation',
#  'of',
#  'this',
#  'approach',
#  'in',
#  'context',
#  'of',
#  'the',
#  'am',
#  'ount',
#  'of',
#  'service',
#  'received',
#  'by',
#  'certain',
#  'nodes',
#  'called',
#  'policy',
#  'execution',
#  'points',
#  'peps',
#  'or',
#  'policy',
#  'clients',
#  'from',
#  'certain',
#  'specialized',
#  'nodes',
#  'called',
#  'the',
#  'policy',
#  'decision',
#  'points',
#  'pdps',
#  'or',
#  'policy',
#  'servers',
#  'we',
#  'develop',
#  'analytical',
#  'models',
#  'for',
#  'the',
#  'study',
#  'of',
#  'the',
#  'system',
#  'behavior',
#  'under',
#  'two',
#  'scenarios',
#  'simple',
#  'markovian',
#  'scenario',
#  'where',
#  'we',
#  'assume',
#  'that',
#  'the',
#  'random',
#  'variables',
#  'associated',
#  'with',
#  'system',
#  'processes',
#  'follow',
#  'an',
#  'exponential',
#  'distribut',
#  'ion',
#  'and',
#  'more',
#  'complex',
#  'non',
#  'markovian',
#  'scenario',
#  'where',
#  'we',
#  'model',
#  'the',
#  'system',
#  'processes',
#  'according',
#  'to',
#  'general',
#  'distribution',
#  'functions',
#  'as',
#  'observed',
#  'through',
#  'simulation',
#  'we',
#  'illustrate',
#  'that',
#  'the',
#  'simplified',
#  'markovian',
#  'model',
#  'provides',
#  'reasonable',
#  'indication',
#  'of',
#  'the',
#  'trend',
#  'of',
#  'the',
#  'service',
#  'availability',
#  'seen',
#  'by',
#  'policy',
#  'clients',
#  'and',
#  'highlight',
#  'the',
#  'need',
#  'for',
#  'an',
#  'ex',
#  'act',
#  'analysis',
#  'of',
#  'the',
#  'system',
#  'without',
#  'relying',
#  'on',
#  'poisson',
#  'assumptions',
#  'for',
#  'system',
#  'processes',
#  'in',
#  'the',
#  'case',
#  'of',
#  'the',
#  'more',
#  'exact',
#  'non',
#  'markovian',
#  'analysis',
#  'we',
#  'show',
#  'that',
#  'our',
#  'model',
#  'gives',
#  'close',
#  'approximation',
#  'to',
#  'the',
#  'values',
#  'obtained',
#  'via',
#  'empirical',
#  'methods',
#  'stochastic',
#  'petri',
#  'nets',
#  'are',
#  'used',
#  'as',
#  'performance',
#  'evaluation',
#  'tools',
#  'in',
#  'development',
#  'and',
#  'analysis',
#  'of',
#  'these',
#  'system',
#  'models',
#  'would',
#  'like',
#  'to',
#  'take',
#  'this',
#  'opportunity',
#  'to',
#  'express',
#  'my',
#  'deep',
#  'ppreciation',
#  'and',
#  'thanks',
#  'to',
#  'all',
#  'those',
#  'who',
#  'helped',
#  'me',
#  'through',
#  'the',
#  'process',
#  'of',
#  'conducting',
#  'this',
#  'research',
#  'first',
#  'and',
#  'foremost',
#  'am',
#  'truly',
#  'grateful',
#  'to',
#  'dr',
#  'luiz',
#  'dasilva',
#  'for',
#  'his',
#  'constant',
#  'support',
#  'and',
#  'encouragement',
#  'throughout',
#  'this',
#  'research',
#  'journey',
#  'he',
#  'was',
#  'an',
#  'in',
#  'cessant',
#  'motivating',
#  'force',
#  'in',
#  'realizing',
#  'this',
#  'thesis',
#  'he',
#  'was',
#  'extrem',
#  'ely',
#  'patient',
#  'and',
#  'always',
#  'provided',
#  'me',
#  'with',
#  'an',
#  'active',
#  'ear',
#  'to',
#  'all',
#  'the',
#  'queries',
#  'and',
#  'problems',
#  'encountered',
#  'during',
#  'the',
#  'course',
#  'of',
#  'this',
#  'research',
#  'his',
#  'relentless',
#  'efforts',
#  'to',
#  'improve',
#  'my',
#  'technical',
#  'writing',
#  'skills',
#  'are',
#  'commendable',
#  'would',
#  'also',
#  'like',
#  'to',
#  'thank',
#  'dr',
#  'kaustubh',
#  'phanse',
#  'for',
#  'his',
#  'instrumental',
#  'role',
#  'in',
#  'driving',
#  'me',
#  'to',
#  'conduct',
#  'research',
#  'in',
#  'this',
#  'area',
#  'truly',
#  'laid',
#  'the',
#  'foundation',
#  'for',
#  'this',
#  'research',
#  'by',
#  'his',
#  'own',
#  'doctoral',
#  'work',
#  'and',
#  'always',
#  'provided',
#  'guiding',
#  'hand',
#  'through',
#  'all',
#  'the',
#  'time',
#  'he',
#  'was',
#  'at',
#  'virginia',
#  'tech',
#  'away',
#  'from',
#  'virginia',
#  'tech',
#  'he',
#  'has',
#  'been',
#  'doing',
#  'all',
#  'he',
#  'can',
#  'in',
#  'his',
#  'ability',
#  'as',
#  'mentor',
#  'and',
#  'committee',
#  'member',
#  'to',
#  'help',
#  'me',
#  'through',
#  'various',
#  'technical',
#  'and',
#  'non',
#  'technical',
#  'difficulties',
#  'faced',
#  'one',
#  'person',
#  'who',
#  'has',
#  'always',
#  'awed',
#  'me',
#  'as',
#  'teac',
#  'her',
#  'and',
#  'researcher',
#  'is',
#  'dr',
#  'midkiff',
#  'he',
#  'has',
#  'always',
#  'been',
#  'fountain',
#  'of',
#  'knowledge',
#  'and',
#  'has',
#  'helped',
#  'me',
#  'strengthen',
#  'my',
#  'basic',
#  'knowledge',
#  'of',
#  'networking',
#  'by',
#  'teaching',
#  'fundamental',
#  'courses',
#  'in',
#  'computer',
#  'networks',
#  'at',
#  'virginia',
#  'tech',
#  'am',
#  'also',
#  'thankful',
#  'to',
#  'him',
#  'for',
#  'providing',
#  'me',
#  'access',
#  'to',
#  'the',
#  'networking',
#  'laboratory',
#  'facilities',
#  'in',
#  'torgersen',
#  'hall',
#  'would',
#  'also',
#  'like',
#  'to',
#  'thank',
#  'dr',
#  'thomas',
#  'hou',
#  'for',
#  'his',
#  'support',
#  'and',
#  'help',
#  'in',
#  'providing',
#  'me',
#  'with',
#  'necessary',
#  'facilities',
#  'he',
#  'has',
#  'been',
#  'tremendous',
#  'influence',
#  'as',
#  'researcher',
#  'with',
#  'the',
#  'amount',
#  'of',
#  'effort',
#  'and',
#  'time',
#  'he',
#  'puts',
#  'into',
#  'his',
#  'research',
#  'his',
#  'technical',
#  'acumen',
#  'and',
#  'ability',
#  'to',
#  'understand',
#  'problem',
#  'are',
#  'phenomenal',
#  'many',
#  'thanks',
#  'to',
#  'dr',
#  'jahng',
#  'park',
#  'for',
#  'helping',
#  'me',
#  'in',
#  'logistic',
#  'issues',
#  'regarding',
#  'equipment',
#  'in',
#  'the',
#  'networking',
#  'lab',
#  'special',
#  'thanks',
#  'to',
#  'dr',
#  'srinidhi',
#  'varadarajan',
#  'and',
#  'all',
#  'members',
#  'of',
#  'the',
#  'committee',
#  'for',
#  'agreeing',
#  'to',
#  'be',
#  'part',
#  'of',
#  'the',
#  'thesis',
#  'committee',
#  'and',
#  'providing',
#  'time',
#  'and',
#  'co',
#  'operation',
#  'in',
#  'reviewing',
#  'this',
#  'work',
#  'express',
#  'my',
#  'deep',
#  'gratitude',
#  'to',
#  'marco',
#  'scarpa',
#  'at',
#  'the',
#  'university',
#  'of',
#  'catania',
#  'italy',
#  'and',
#  'dr',
#  'telek',
#  'miklos',
#  'at',
#  'the',
#  'budapest',
#  'university',
#  'of',
#  'technology',
#  'and',
#  'economics',
#  'for',
#  'their',
#  'support',
#  'and',
#  'patience',
#  'in',
#  'answering',
#  'my',
#  'queries',
#  'regarding',
#  'the',
#  'use',
#  'of',
#  'webspn',
#  'and',
#  'phfit',
#  'tools',
#  'iii',
#  'thanks',
#  'to',
#  'karthik',
#  'channakeshava',
#  'gaurav',
#  'joshi',
#  'and',
#  'vivek',
#  'srivastava',
#  'for',
#  'being',
#  'wonderful',
#  'friends',
#  'they',
#  'helped',
#  'through',
#  'my',
#  'research',
#  'at',
#  'various',
#  'levels',
#  'and',
#  'provided',
#  'me',
#  'with',
#  'some',
#  'social',
#  'life',
#  'in',
#  'an',
#  'otherwise',
#  'techn',
#  'ical',
#  'venture',
#  'last',
#  'but',
#  'not',
#  'the',
#  'least',
#  'heartfelt',
#  'thanks',
#  'to',
#  'all',
#  'friends',
#  'family',
#  'members',
#  'and',
#  'others',
#  'whose',
#  'names',
#  'do',
#  'not',
#  'appear',
#  'here',
#  'but',
#  'have',
#  'been',
#  'instrumental',
#  'to',
#  'my',
#  'success',
#  'during',
#  'this',
#  'journey',
#  'of',
#  'two',
#  'years',
#  'iv',
#  'table',
#  'of',
#  'contents',
#  'chapter',
#  'introduction',
#  'motiva',
#  'tion',
#  'the',
#  'pbnm',
#  'system',
#  'importance',
#  'of',
#  'modeling',
#  'structure',
#  'of',
#  'the',
#  'document',
#  'chapter',
#  'background',
#  'and',
#  'rel',
#  'ated',
#  'work',
#  'petri',
#  'net',
#  'theory',
#  'classification',
#  'of',
#  'petri',
#  'nets',
#  'timed',
#  'petri',
#  'nets',
#  'stochastic',
#  'petri',
#  'nets',
#  'generalized',
#  'stochastic',
#  'etri',
#  'nets',
#  'generally',
#  'distributed',
#  'transi',
#  'tion',
#  'stochastic',
#  'petri',
#  'nets',
#  'phase',
#  'type',
#  'stochastic',
#  'petri',
#  'nets',
#  'applications',
#  'of',
#  'petri',
#  'net',
#  'theory',
#  'to',
#  'computer',
#  'networks',
#  'analytical',
#  'models',
#  'for',
#  'computer',
#  'networks',
#  'focus',
#  'on',
#  'modeling',
#  'of',
#  'ireless',
#  'networks',
#  'summary',
#  'chapter',
#  'empiri',
#  'cal',
#  'model',
#  'parameter',
#  'of',
#  'interest',
#  'sim',
#  'ulation',
#  'methodology',
#  'the',
#  'qualnet',
#  'network',
#  'simulator',
#  'sim',
#  'ulation',
#  'environment',
#  'basic',
#  'scenarios',
#  'effect',
#  'of',
#  'mobility',
#  'and',
#  'cluster',
#  'size',
#  'on',
#  'service',
#  'availability',
#  'effect',
#  'of',
#  'mobility',
#  'and',
#  'cluster',
#  'size',
#  'on',
#  'effect',
#  'of',
#  'mobility',
#  'and',
#  'cluster',
#  'size',
#  'on',
#  'effect',
#  'of',
#  'mobility',
#  'and',
#  'cluster',
#  'size',
#  'on',
#  'histogram',
#  'study',
#  'of',
#  'variation',
#  'of',
#  'ka',
#  'timer',
#  'and',
#  'pause',
#  'times',
#  'summa',
#  'ry',
#  'chapter',
#  'markovian',
#  'analysis',
#  'generalized',
#  'stochastic',
#  'petri',
#  'net',
#  'model',
#  'for',
#  'clients',
#  'in',
#  'pbnm',
#  'system',
#  'equivalent',
#  'network',
#  'of',
#  'queues',
#  'model',
#  'mathematical',
#  'solution',
#  'with',
#  'markovian',
#  'assumptions',
#  'gspn',
#  'model',
#  'validation',
#  'implementation',
#  'tools',
#  'and',
#  'methodology',
#  'empirical',
#  'of',
#  'the',
#  'gspn',
#  'model',
#  'and',
#  'results',
#  'limitations',
#  'of',
#  'the',
#  'markov',
#  'model',
#  'summa',
#  'ry',
#  'chapter',
#  'non',
#  'arkovian',
#  'analysis',
#  'development',
#  'of',
#  'the',
#  'gdt_spn',
#  'model',
#  're',
#  'visiting',
#  'phase',
#  'ype',
#  'distributions',
#  'non',
#  'markovian',
#  'model',
#  'analysis',
#  'methodology',
#  'phfit',
#  'analysis',
#  'validation',
#  'of',
#  'the',
#  'gdt_spn',
#  'model',
#  'webspn',
#  'non',
#  'markovian',
#  'spn',
#  'tool',
#  'model',
#  'validation',
#  'and',
#  'results',
#  'summa',
#  'ry',
#  'vi',
#  'chapter',
#  'conclusions',
#  'and',
#  'future',
#  'work',
#  'contributions',
#  'of',
#  'this',
#  'resear',
#  'ch',
#  'directions',
#  'for',
#  'future',
#  'work',
#  'thesis',
#  'summary',
#  'bibliography',
#  'glossary',
#  'appendix',
#  'vii',
#  'list',
#  'of',
#  'figures',
#  'figure',
#  'fundamental',
#  'elements',
#  'of',
#  'policy',
#  'based',
#  'management',
#  'system',
#  'figure',
#  'hop',
#  'cluster',
#  'management',
#  'algorithm',
#  'figure',
#  'graphical',
#  ...]
