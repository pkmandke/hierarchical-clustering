# %% [markdown]
# # Visualizing and analyzing results

# %%
import gensim
import nltk
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
nltk.download('punkt')
nltk.download('stopwords')
import pandas as pd
import os
import string
import numpy as np

import joblib
# Out:
# [nltk_data] Downloading package punkt to /home/pkmandke/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/pkmandke/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# Custom defined imports

from agglo_clus import Agglo_clus as ag
from pre_process import Doc2vec_wrapper, extract_mapped_doc2vecs

# %% [markdown]
# # Some helper functions

# %%
def setify(depts):
    unq = []
    for st in depts:
        if st in unq:
            continue
        unq.append(st)
    return unq

def get_unique_field(df, field):
    
    return setify(df[field])

def find_docs_in_cluster(df, idx, clust):
    
    return df.loc[df['identifier-uri'].isin([clust.doc_names[_] for _ in idx])]

def get_index_of_docs(clust_object, clust_num=8):
    return [idx for idx, _ in enumerate(clust_object.predictions) if _ == clust_num]
    
def read_docvec_model(path):
    
    return gensim.models.doc2vec.Doc2Vec.load(path)

def get_docs_per_cluster(model, num_classes):
    
    return [len(model.predictions[model.predictions == i]) for i in range(num_classes)]

# Helpers for kmeans

def get_kmeans_map_dict(km_model):
    
    kmap_dict = dict()

    for l in list(set(km_model.km.labels_)):
        for _ in km_model.km.labels_:
            if _ == l:
                if l in kmap_dict.keys():
                    kmap_dict[l] += 1
                else:
                    kmap_dict[l] = 1
                
    return kmap_dict

def kmeans_get_docs_with_idx(km_model, idx):
    
    docs = []
    
    for ix, _ in enumerate(km_model.km.labels_):
        
        if _ == idx:
            
            docs.append(km_model.doc_list[ix])
    
    return docs

# %% [markdown]
# # Compute hierarchical clustering

# %%
# Paths

DOCVEC_MODEL = '../obj/doc2vec/abstracts_etd_doc2vec_all_docs30961_docs'
NUM_CLUS = 500

# %%
doc_vectors, keys = extract_mapped_doc2vecs(read_docvec_model(DOCVEC_MODEL))

print(len(doc_vectors))
# Out:
# 23140

# %%
doc_vectors, keys = extract_mapped_doc2vecs(read_docvec_model(DOCVEC_MODEL))

ag_model = ag(doc_vectors, doc_names = keys, num_clus = NUM_CLUS, linkage='ward', affinity='euclidean', iter_='1')

ag_model.clusterize()
# Out:
# Starting clustering...
# Done training in 0:00:28.063638s

# %%
ag_model.save('ag_clus_full_data_trial.sav')

# %% [markdown]
# # Analyze results

# %%
ag_model = joblib.load('../obj/agglo_clus/iter_1/ag_clus_full_data_trial.sav')

# %%
# Read JSON metadata

dframe = pd.read_json('../data/30Kmetadata.json', orient=str, lines=True)[['identifier-uri',\
                                                                           'contributor-department', 'searchTitle']]

pd.options.display.max_rows = 40000

# %%
max(get_docs_per_cluster(ag_model, num_classes=NUM_CLUS))  # Get number of documents on each cluster
# Out:
# 911

# %%
idx = get_index_of_docs(ag_model, clust_num=10) # Find index of docs in a particular cluster

doc_urls = find_docs_in_cluster(dframe, idx, ag_model) # Get documents belonging to that cluster

unique_field = get_unique_field(doc_urls, 'contributor-department')
unique_field, len(doc_urls)
# Out:
# (['Electrical and Computer Engineering ', 'Electrical Engineering '], 32)

# %%
idx = get_index_of_docs(ag_model, clust_num=20) # Find index of docs in a particular cluster

doc_urls = find_docs_in_cluster(dframe, idx, ag_model) # Get documents belonging to that cluster

unique_field = get_unique_field(doc_urls, 'contributor-department')
unique_field, len(doc_urls)
# Out:
# (['Mechanical Engineering ',
#   'Civil Engineering ',
#   'Engineering Science and Mechanics ',
#   'Aerospace and Ocean Engineering ',
#   'Aerospace Engineering ',
#   'Engineering Mechanics ',
#   'Civil and Environmental Engineering '],
#  82)

# %%
doc_urls
# Out:
#                            identifier-uri  \
# 565    http://hdl.handle.net/10919/19257
# 747    http://hdl.handle.net/10919/23272
# 879    http://hdl.handle.net/10919/24827
# 901    http://hdl.handle.net/10919/25288
# 991    http://hdl.handle.net/10919/30847
# 998    http://hdl.handle.net/10919/30854
# 1128   http://hdl.handle.net/10919/30992
# 1147   http://hdl.handle.net/10919/31011
# 1411   http://hdl.handle.net/10919/31297
# 1494   http://hdl.handle.net/10919/31385
# 1925   http://hdl.handle.net/10919/31854
# 1981   http://hdl.handle.net/10919/31912
# 2851   http://hdl.handle.net/10919/32841
# 3896   http://hdl.handle.net/10919/33990
# 3944   http://hdl.handle.net/10919/34040
# 4037   http://hdl.handle.net/10919/34141
# 4438   http://hdl.handle.net/10919/34583
# 4648   http://hdl.handle.net/10919/34809
# 4992   http://hdl.handle.net/10919/35186
# 5011   http://hdl.handle.net/10919/35205
# 5336   http://hdl.handle.net/10919/35574
# 5667   http://hdl.handle.net/10919/35938
# 5831   http://hdl.handle.net/10919/36121
# 6101   http://hdl.handle.net/10919/36408
# 7187   http://hdl.handle.net/10919/40924
# 9727   http://hdl.handle.net/10919/43488
# 10288  http://hdl.handle.net/10919/44054
# 12305  http://hdl.handle.net/10919/46084
# 14397  http://hdl.handle.net/10919/54577
# 15528  http://hdl.handle.net/10919/71323
# 15544  http://hdl.handle.net/10919/71352
# 16435  http://hdl.handle.net/10919/76251
# 16614  http://hdl.handle.net/10919/76764
# 16628  http://hdl.handle.net/10919/76778
# 16631  http://hdl.handle.net/10919/76781
# 16640  http://hdl.handle.net/10919/76790
# 16665  http://hdl.handle.net/10919/76815
# 16713  http://hdl.handle.net/10919/76863
# 16852  http://hdl.handle.net/10919/77004
# 16865  http://hdl.handle.net/10919/77017
# 16883  http://hdl.handle.net/10919/77473
# 16970  http://hdl.handle.net/10919/77924
# 17077  http://hdl.handle.net/10919/78110
# 17727  http://hdl.handle.net/10919/81836
# 17770  http://hdl.handle.net/10919/82039
# 18126  http://hdl.handle.net/10919/19206
# 18398  http://hdl.handle.net/10919/25801
# 18498  http://hdl.handle.net/10919/26039
# 19488  http://hdl.handle.net/10919/27066
# 19898  http://hdl.handle.net/10919/27507
# 20443  http://hdl.handle.net/10919/28080
# 20530  http://hdl.handle.net/10919/28171
# 20898  http://hdl.handle.net/10919/28560
# 20984  http://hdl.handle.net/10919/28653
# 21157  http://hdl.handle.net/10919/28833
# 21210  http://hdl.handle.net/10919/28886
# 21453  http://hdl.handle.net/10919/29145
# 21652  http://hdl.handle.net/10919/29358
# 22005  http://hdl.handle.net/10919/29727
# 22130  http://hdl.handle.net/10919/29856
# 22132  http://hdl.handle.net/10919/29858
# 22275  http://hdl.handle.net/10919/30011
# 22458  http://hdl.handle.net/10919/30202
# 22772  http://hdl.handle.net/10919/30527
# 22987  http://hdl.handle.net/10919/30743
# 23114  http://hdl.handle.net/10919/37273
# 23827  http://hdl.handle.net/10919/37993
# 23915  http://hdl.handle.net/10919/38081
# 25611  http://hdl.handle.net/10919/39790
# 27043  http://hdl.handle.net/10919/51747
# 28291  http://hdl.handle.net/10919/64501
# 28759  http://hdl.handle.net/10919/72912
# 28982  http://hdl.handle.net/10919/73987
# 29344  http://hdl.handle.net/10919/75043
# 29844  http://hdl.handle.net/10919/77168
# 29871  http://hdl.handle.net/10919/77196
# 29877  http://hdl.handle.net/10919/77202
# 29917  http://hdl.handle.net/10919/77242
# 30287  http://hdl.handle.net/10919/77979
# 30363  http://hdl.handle.net/10919/78358
# 30487  http://hdl.handle.net/10919/79726
# 30916  http://hdl.handle.net/10919/82921
#
#                      contributor-department  \
# 565                 Mechanical Engineering
# 747                 Mechanical Engineering
# 879                 Mechanical Engineering
# 901                 Mechanical Engineering
# 991                 Mechanical Engineering
# 998                 Mechanical Engineering
# 1128                Mechanical Engineering
# 1147                Mechanical Engineering
# 1411                Mechanical Engineering
# 1494                Mechanical Engineering
# 1925                Mechanical Engineering
# 1981                Mechanical Engineering
# 2851                Mechanical Engineering
# 3896                Mechanical Engineering
# 3944                Mechanical Engineering
# 4037                Mechanical Engineering
# 4438                Mechanical Engineering
# 4648                     Civil Engineering
# 4992                Mechanical Engineering
# 5011                Mechanical Engineering
# 5336     Engineering Science and Mechanics
# 5667       Aerospace and Ocean Engineering
# 5831                Mechanical Engineering
# 6101                Mechanical Engineering
# 7187                     Civil Engineering
# 9727                Mechanical Engineering
# 10288                Aerospace Engineering
# 12305                Engineering Mechanics
# 14397               Mechanical Engineering
# 15528               Mechanical Engineering
# 15544               Mechanical Engineering
# 16435               Mechanical Engineering
# 16614               Mechanical Engineering
# 16628               Mechanical Engineering
# 16631               Mechanical Engineering
# 16640               Mechanical Engineering
# 16665               Mechanical Engineering
# 16713               Mechanical Engineering
# 16852               Mechanical Engineering
# 16865               Mechanical Engineering
# 16883      Aerospace and Ocean Engineering
# 16970               Mechanical Engineering
# 17077               Mechanical Engineering
# 17727               Mechanical Engineering
# 17770               Mechanical Engineering
# 18126               Mechanical Engineering
# 18398               Mechanical Engineering
# 18498               Mechanical Engineering
# 19488               Mechanical Engineering
# 19898               Mechanical Engineering
# 20443               Mechanical Engineering
# 20530               Mechanical Engineering
# 20898               Mechanical Engineering
# 20984               Mechanical Engineering
# 21157               Mechanical Engineering
# 21210      Aerospace and Ocean Engineering
# 21453               Mechanical Engineering
# 21652               Mechanical Engineering
# 22005               Mechanical Engineering
# 22130               Mechanical Engineering
# 22132               Mechanical Engineering
# 22275               Mechanical Engineering
# 22458               Mechanical Engineering
# 22772               Mechanical Engineering
# 22987      Aerospace and Ocean Engineering
# 23114                Aerospace Engineering
# 23827               Mechanical Engineering
# 23915               Mechanical Engineering
# 25611               Mechanical Engineering
# 27043               Mechanical Engineering
# 28291               Mechanical Engineering
# 28759               Mechanical Engineering
# 28982               Mechanical Engineering
# 29344  Civil and Environmental Engineering
# 29844      Aerospace and Ocean Engineering
# 29871               Mechanical Engineering
# 29877               Mechanical Engineering
# 29917               Mechanical Engineering
# 30287               Mechanical Engineering
# 30363               Mechanical Engineering
# 30487               Mechanical Engineering
# 30916               Mechanical Engineering
#
#                                              searchTitle
# 565    aerodynamics of endwall contouring with discre...
# 747    effect of blitype inlet distortion on turbofan...
# 879    experimental study of the heat transfer on a s...
# 901    the influence of development and fanscreen int...
# 991    flow control optimization for improvement of f...
# 998    measurements and predictions of heat transfer ...
# 1128   flow field computations of combustorturbine in...
# 1147   effects of flow control on the aerodynamics of...
# 1411   aerodynamic performance of a flow controlled c...
# 1494   noise reduction in an axisymmetric supersonic ...
# 1925   reduction of unsteady statorrotor interaction ...
# 1981   endwall heat transfer and shear stress for a n...
# 2851   boundary layer control and wallpressure fluctu...
# 3896   wake filling techniques for reducing rotorstat...
# 3944   advanced trailing edge blowing concepts for fa...
# 4037   practical applications of delta winglets in co...
# 4438   aerodynamic measurements in a wind tunnel on s...
# 4648   simulationbased analysis of wake turbulence en...
# 4992   predictions and measurements of filmcooling on...
# 5011   study of steadystate wake characteristics of v...
# 5336   concept study of a highspeed vertical takeoff ...
# 5667   gap size effect on low reynolds number wind tu...
# 5831   effects of realistic firststage turbine endwal...
# 6101   measurements of flow in boundary layer ingesti...
# 7187   analysis of potential wake turbulence encounte...
# 9727   cfd analysis and redesign of centrifugal impel...
# 10288         end plate gap effects on a halfwing model
# 12305  effect of humps on the stability of boundary l...
# 14397  aerodynamic performance of a transonic turbine...
# 15528  experimental investigation of fan rotor respon...
# 15544  heat transfer performance improvement technolo...
# 16435  head augmentation in hydraulic turbines by mea...
# 16614  effects of tip clearance gap and exit mach num...
# 16628  performance of a showerhead and shaped hole fi...
# 16631  film cooling predictions along the tip and pla...
# 16640  heat transfer coefficient and adiabatic effect...
# 16665  measurements of cooling effectiveness along th...
# 16713  effects of sand ingestion on the filmcooling o...
# 16852  internal heat transfer and external effectiven...
# 16865  adiabatic effectiveness measurements of leakag...
# 16883  generation of downstream vorticity through the...
# 16970  aerodynamic investigation of upstream misalign...
# 17077  the effect of combustor exit to nozzle guide v...
# 17727  a fundamental study of advance ratio solidity ...
# 17770  new methodology for the estimation  of streamv...
# 18126  design analysis and development of a tripod fi...
# 18398  experimental study of gas turbine endwall cool...
# 18498  numerical investigation of subsonic axialflow ...
# 19488  effects of surface conditions on endwall filmc...
# 19898  an improved streamline curvature approach for ...
# 20443  modeling of herschelquinckeliner systems for t...
# 20530  experimental study of the effect of dilution j...
# 20898  showerhead film cooling performance of a turbi...
# 20984  effectiveness of a serpentine inlet duct flow ...
# 21157  investigation of inlet guide vane wakes in a f...
# 21210  clean wing airframe noise modeling for multidi...
# 21453  parametric investigation of the combustorturbi...
# 21652  effects of riblets on the performance of the s...
# 22005  experimental and numerical investigations of o...
# 22130  a detailed study of fanshaped filmcooling for ...
# 22132  large eddy simulations of flow and heat transf...
# 22275  assessment of a leading edge fillet for decrea...
# 22458  a performance study of a supercruise engine wi...
# 22772  reduction of unsteady rotorstator interaction ...
# 22987  a cfdcsd interaction methodology for aircraft ...
# 23114  experimental and numerical investigation of tr...
# 23827     flow losses in supersonic compressor cascades
# 23915  a threedimensional turbine engine analysis com...
# 25611  experimental studies in a supersonic throughfl...
# 27043  measurement and uncertainty analysis of transo...
# 28291  heat transfer and flow characteristics on the ...
# 28759  analysis of film cooling performance of tripod...
# 28982  full scale experimental transonic fan interact...
# 29344  a computer model to predict potential wake tur...
# 29844  optimization under uncertainty and total predi...
# 29871  aerodynamic performance of high turning airfoi...
# 29877  the effect of endwall contouring on boundary l...
# 29917  development of a robust numerical optimization...
# 30287  fanshaped hole film cooling on turbine blade a...
# 30363  development of advanced internal cooling techn...
# 30487  developing and testing a combustor simulator f...
# 30916  fluid dynamics of inlet swirl distortions for ...

# %% [markdown]
# # Analyze kmeans results

# %%
km_model = joblib.load('../obj/kmeans/iter_2/abstracts_etd_doc2vec_all_docs30961_docs_kmeans.sav')

# %%
len(km_model.km.labels_)
# Out:
# 23140

# %%
help(km_model.km)
# Out:
# Help on KMeans in module sklearn.cluster.k_means_ object:
#
# class KMeans(sklearn.base.BaseEstimator, sklearn.base.ClusterMixin, sklearn.base.TransformerMixin)
#  |  K-Means clustering
#  |
#  |  Read more in the :ref:`User Guide <k_means>`.
#  |
#  |  Parameters
#  |  ----------
#  |
#  |  n_clusters : int, optional, default: 8
#  |      The number of clusters to form as well as the number of
#  |      centroids to generate.
#  |
#  |  init : {'k-means++', 'random' or an ndarray}
#  |      Method for initialization, defaults to 'k-means++':
#  |
#  |      'k-means++' : selects initial cluster centers for k-mean
#  |      clustering in a smart way to speed up convergence. See section
#  |      Notes in k_init for more details.
#  |
#  |      'random': choose k observations (rows) at random from data for
#  |      the initial centroids.
#  |
#  |      If an ndarray is passed, it should be of shape (n_clusters, n_features)
#  |      and gives the initial centers.
#  |
#  |  n_init : int, default: 10
#  |      Number of time the k-means algorithm will be run with different
#  |      centroid seeds. The final results will be the best output of
#  |      n_init consecutive runs in terms of inertia.
#  |
#  |  max_iter : int, default: 300
#  |      Maximum number of iterations of the k-means algorithm for a
#  |      single run.
#  |
#  |  tol : float, default: 1e-4
#  |      Relative tolerance with regards to inertia to declare convergence
#  |
#  |  precompute_distances : {'auto', True, False}
#  |      Precompute distances (faster but takes more memory).
#  |
#  |      'auto' : do not precompute distances if n_samples * n_clusters > 12
#  |      million. This corresponds to about 100MB overhead per job using
#  |      double precision.
#  |
#  |      True : always precompute distances
#  |
#  |      False : never precompute distances
#  |
#  |  verbose : int, default 0
#  |      Verbosity mode.
#  |
#  |  random_state : int, RandomState instance or None (default)
#  |      Determines random number generation for centroid initialization. Use
#  |      an int to make the randomness deterministic.
#  |      See :term:`Glossary <random_state>`.
#  |
#  |  copy_x : boolean, optional
#  |      When pre-computing distances it is more numerically accurate to center
#  |      the data first.  If copy_x is True (default), then the original data is
#  |      not modified, ensuring X is C-contiguous.  If False, the original data
#  |      is modified, and put back before the function returns, but small
#  |      numerical differences may be introduced by subtracting and then adding
#  |      the data mean, in this case it will also not ensure that data is
#  |      C-contiguous which may cause a significant slowdown.
#  |
#  |  n_jobs : int or None, optional (default=None)
#  |      The number of jobs to use for the computation. This works by computing
#  |      each of the n_init runs in parallel.
#  |
#  |      ``None`` means 1 unless in a :obj:`joblib.parallel_backend` context.
#  |      ``-1`` means using all processors. See :term:`Glossary <n_jobs>`
#  |      for more details.
#  |
#  |  algorithm : "auto", "full" or "elkan", default="auto"
#  |      K-means algorithm to use. The classical EM-style algorithm is "full".
#  |      The "elkan" variation is more efficient by using the triangle
#  |      inequality, but currently doesn't support sparse data. "auto" chooses
#  |      "elkan" for dense data and "full" for sparse data.
#  |
#  |  Attributes
#  |  ----------
#  |  cluster_centers_ : array, [n_clusters, n_features]
#  |      Coordinates of cluster centers. If the algorithm stops before fully
#  |      converging (see ``tol`` and ``max_iter``), these will not be
#  |      consistent with ``labels_``.
#  |
#  |  labels_ :
#  |      Labels of each point
#  |
#  |  inertia_ : float
#  |      Sum of squared distances of samples to their closest cluster center.
#  |
#  |  n_iter_ : int
#  |      Number of iterations run.
#  |
#  |  Examples
#  |  --------
#  |
#  |  >>> from sklearn.cluster import KMeans
#  |  >>> import numpy as np
#  |  >>> X = np.array([[1, 2], [1, 4], [1, 0],
#  |  ...               [10, 2], [10, 4], [10, 0]])
#  |  >>> kmeans = KMeans(n_clusters=2, random_state=0).fit(X)
#  |  >>> kmeans.labels_
#  |  array([1, 1, 1, 0, 0, 0], dtype=int32)
#  |  >>> kmeans.predict([[0, 0], [12, 3]])
#  |  array([1, 0], dtype=int32)
#  |  >>> kmeans.cluster_centers_
#  |  array([[10.,  2.],
#  |         [ 1.,  2.]])
#  |
#  |  See also
#  |  --------
#  |
#  |  MiniBatchKMeans
#  |      Alternative online implementation that does incremental updates
#  |      of the centers positions using mini-batches.
#  |      For large scale learning (say n_samples > 10k) MiniBatchKMeans is
#  |      probably much faster than the default batch implementation.
#  |
#  |  Notes
#  |  -----
#  |  The k-means problem is solved using either Lloyd's or Elkan's algorithm.
#  |
#  |  The average complexity is given by O(k n T), were n is the number of
#  |  samples and T is the number of iteration.
#  |
#  |  The worst case complexity is given by O(n^(k+2/p)) with
#  |  n = n_samples, p = n_features. (D. Arthur and S. Vassilvitskii,
#  |  'How slow is the k-means method?' SoCG2006)
#  |
#  |  In practice, the k-means algorithm is very fast (one of the fastest
#  |  clustering algorithms available), but it falls in local minima. That's why
#  |  it can be useful to restart it several times.
#  |
#  |  If the algorithm stops before fully converging (because of ``tol`` or
#  |  ``max_iter``), ``labels_`` and ``cluster_centers_`` will not be consistent,
#  |  i.e. the ``cluster_centers_`` will not be the means of the points in each
#  |  cluster. Also, the estimator will reassign ``labels_`` after the last
#  |  iteration to make ``labels_`` consistent with ``predict`` on the training
#  |  set.
#  |
#  |  Method resolution order:
#  |      KMeans
#  |      sklearn.base.BaseEstimator
#  |      sklearn.base.ClusterMixin
#  |      sklearn.base.TransformerMixin
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, n_clusters=8, init='k-means++', n_init=10, max_iter=300, tol=0.0001, precompute_distances='auto', verbose=0, random_state=None, copy_x=True, n_jobs=None, algorithm='auto')
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  fit(self, X, y=None, sample_weight=None)
#  |      Compute k-means clustering.
#  |
#  |      Parameters
#  |      ----------
#  |      X : array-like or sparse matrix, shape=(n_samples, n_features)
#  |          Training instances to cluster. It must be noted that the data
#  |          will be converted to C ordering, which will cause a memory
#  |          copy if the given data is not C-contiguous.
#  |
#  |      y : Ignored
#  |          not used, present here for API consistency by convention.
#  |
#  |      sample_weight : array-like, shape (n_samples,), optional
#  |          The weights for each observation in X. If None, all observations
#  |          are assigned equal weight (default: None)
#  |
#  |  fit_predict(self, X, y=None, sample_weight=None)
#  |      Compute cluster centers and predict cluster index for each sample.
#  |
#  |      Convenience method; equivalent to calling fit(X) followed by
#  |      predict(X).
#  |
#  |      Parameters
#  |      ----------
#  |      X : {array-like, sparse matrix}, shape = [n_samples, n_features]
#  |          New data to transform.
#  |
#  |      y : Ignored
#  |          not used, present here for API consistency by convention.
#  |
#  |      sample_weight : array-like, shape (n_samples,), optional
#  |          The weights for each observation in X. If None, all observations
#  |          are assigned equal weight (default: None)
#  |
#  |      Returns
#  |      -------
#  |      labels : array, shape [n_samples,]
#  |          Index of the cluster each sample belongs to.
#  |
#  |  fit_transform(self, X, y=None, sample_weight=None)
#  |      Compute clustering and transform X to cluster-distance space.
#  |
#  |      Equivalent to fit(X).transform(X), but more efficiently implemented.
#  |
#  |      Parameters
#  |      ----------
#  |      X : {array-like, sparse matrix}, shape = [n_samples, n_features]
#  |          New data to transform.
#  |
#  |      y : Ignored
#  |          not used, present here for API consistency by convention.
#  |
#  |      sample_weight : array-like, shape (n_samples,), optional
#  |          The weights for each observation in X. If None, all observations
#  |          are assigned equal weight (default: None)
#  |
#  |      Returns
#  |      -------
#  |      X_new : array, shape [n_samples, k]
#  |          X transformed in the new space.
#  |
#  |  predict(self, X, sample_weight=None)
#  |      Predict the closest cluster each sample in X belongs to.
#  |
#  |      In the vector quantization literature, `cluster_centers_` is called
#  |      the code book and each value returned by `predict` is the index of
#  |      the closest code in the code book.
#  |
#  |      Parameters
#  |      ----------
#  |      X : {array-like, sparse matrix}, shape = [n_samples, n_features]
#  |          New data to predict.
#  |
#  |      sample_weight : array-like, shape (n_samples,), optional
#  |          The weights for each observation in X. If None, all observations
#  |          are assigned equal weight (default: None)
#  |
#  |      Returns
#  |      -------
#  |      labels : array, shape [n_samples,]
#  |          Index of the cluster each sample belongs to.
#  |
#  |  score(self, X, y=None, sample_weight=None)
#  |      Opposite of the value of X on the K-means objective.
#  |
#  |      Parameters
#  |      ----------
#  |      X : {array-like, sparse matrix}, shape = [n_samples, n_features]
#  |          New data.
#  |
#  |      y : Ignored
#  |          not used, present here for API consistency by convention.
#  |
#  |      sample_weight : array-like, shape (n_samples,), optional
#  |          The weights for each observation in X. If None, all observations
#  |          are assigned equal weight (default: None)
#  |
#  |      Returns
#  |      -------
#  |      score : float
#  |          Opposite of the value of X on the K-means objective.
#  |
#  |  transform(self, X)
#  |      Transform X to a cluster-distance space.
#  |
#  |      In the new space, each dimension is the distance to the cluster
#  |      centers.  Note that even if X is sparse, the array returned by
#  |      `transform` will typically be dense.
#  |
#  |      Parameters
#  |      ----------
#  |      X : {array-like, sparse matrix}, shape = [n_samples, n_features]
#  |          New data to transform.
#  |
#  |      Returns
#  |      -------
#  |      X_new : array, shape [n_samples, k]
#  |          X transformed in the new space.
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from sklearn.base.BaseEstimator:
#  |
#  |  __getstate__(self)
#  |
#  |  __repr__(self, N_CHAR_MAX=700)
#  |      Return repr(self).
#  |
#  |  __setstate__(self, state)
#  |
#  |  get_params(self, deep=True)
#  |      Get parameters for this estimator.
#  |
#  |      Parameters
#  |      ----------
#  |      deep : boolean, optional
#  |          If True, will return the parameters for this estimator and
#  |          contained subobjects that are estimators.
#  |
#  |      Returns
#  |      -------
#  |      params : mapping of string to any
#  |          Parameter names mapped to their values.
#  |
#  |  set_params(self, **params)
#  |      Set the parameters of this estimator.
#  |
#  |      The method works on simple estimators as well as on nested objects
#  |      (such as pipelines). The latter have parameters of the form
#  |      ``<component>__<parameter>`` so that it's possible to update each
#  |      component of a nested object.
#  |
#  |      Returns
#  |      -------
#  |      self
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from sklearn.base.BaseEstimator:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)

# %%
kmap_dict = get_kmeans_map_dict(km_model)
kmap_dict
# Out:
# {0: 1,
#  1: 101,
#  2: 99,
#  3: 41,
#  4: 135,
#  5: 49,
#  6: 69,
#  7: 94,
#  8: 287,
#  9: 98,
#  10: 207,
#  11: 78,
#  12: 66,
#  13: 19,
#  14: 45,
#  15: 38,
#  16: 169,
#  17: 33,
#  18: 19,
#  19: 26,
#  20: 23,
#  21: 56,
#  22: 23,
#  23: 27,
#  24: 47,
#  25: 1,
#  26: 141,
#  27: 40,
#  28: 63,
#  29: 19,
#  30: 82,
#  31: 1,
#  32: 5,
#  33: 25,
#  34: 2,
#  35: 2,
#  36: 71,
#  37: 171,
#  38: 1,
#  39: 37,
#  40: 39,
#  41: 108,
#  42: 70,
#  43: 9,
#  44: 26,
#  45: 52,
#  46: 32,
#  47: 89,
#  48: 41,
#  49: 64,
#  50: 68,
#  51: 35,
#  52: 104,
#  53: 15,
#  54: 140,
#  55: 41,
#  56: 15,
#  57: 33,
#  58: 50,
#  59: 98,
#  60: 60,
#  61: 46,
#  62: 8,
#  63: 46,
#  64: 34,
#  65: 110,
#  66: 28,
#  67: 2,
#  68: 23,
#  69: 18,
#  70: 3,
#  71: 108,
#  72: 29,
#  73: 25,
#  74: 33,
#  75: 80,
#  76: 95,
#  77: 132,
#  78: 42,
#  79: 49,
#  80: 252,
#  81: 14,
#  82: 97,
#  83: 3,
#  84: 66,
#  85: 17,
#  86: 12,
#  87: 96,
#  88: 37,
#  89: 2,
#  90: 3,
#  91: 1,
#  92: 1,
#  93: 91,
#  94: 46,
#  95: 53,
#  96: 20,
#  97: 7,
#  98: 11,
#  99: 19,
#  100: 25,
#  101: 53,
#  102: 146,
#  103: 489,
#  104: 41,
#  105: 16,
#  106: 31,
#  107: 16,
#  108: 63,
#  109: 35,
#  110: 15,
#  111: 68,
#  112: 64,
#  113: 58,
#  114: 13,
#  115: 53,
#  116: 63,
#  117: 12,
#  118: 55,
#  119: 49,
#  120: 46,
#  121: 29,
#  122: 65,
#  123: 31,
#  124: 1,
#  125: 30,
#  126: 5,
#  127: 1,
#  128: 50,
#  129: 69,
#  130: 30,
#  131: 16,
#  132: 36,
#  133: 37,
#  134: 108,
#  135: 23,
#  136: 1,
#  137: 54,
#  138: 2,
#  139: 4,
#  140: 51,
#  141: 36,
#  142: 114,
#  143: 47,
#  144: 4,
#  145: 73,
#  146: 121,
#  147: 1,
#  148: 44,
#  149: 54,
#  150: 84,
#  151: 81,
#  152: 29,
#  153: 50,
#  154: 4,
#  155: 1,
#  156: 37,
#  157: 4,
#  158: 75,
#  159: 39,
#  160: 14,
#  161: 103,
#  162: 4,
#  163: 90,
#  164: 50,
#  165: 32,
#  166: 128,
#  167: 8,
#  168: 1,
#  169: 32,
#  170: 40,
#  171: 73,
#  172: 59,
#  173: 109,
#  174: 44,
#  175: 4,
#  176: 48,
#  177: 187,
#  178: 461,
#  179: 49,
#  180: 59,
#  181: 20,
#  182: 57,
#  183: 52,
#  184: 20,
#  185: 26,
#  186: 154,
#  187: 115,
#  188: 30,
#  189: 46,
#  190: 8,
#  191: 5,
#  192: 37,
#  193: 42,
#  194: 16,
#  195: 10,
#  196: 53,
#  197: 100,
#  198: 14,
#  199: 10,
#  200: 54,
#  201: 105,
#  202: 3,
#  203: 6,
#  204: 25,
#  205: 33,
#  206: 74,
#  207: 43,
#  208: 30,
#  209: 38,
#  210: 34,
#  211: 22,
#  212: 86,
#  213: 12,
#  214: 127,
#  215: 21,
#  216: 58,
#  217: 33,
#  218: 72,
#  219: 56,
#  220: 16,
#  221: 121,
#  222: 34,
#  223: 1,
#  224: 1,
#  225: 45,
#  226: 60,
#  227: 15,
#  228: 63,
#  229: 134,
#  230: 1,
#  231: 146,
#  232: 32,
#  233: 32,
#  234: 29,
#  235: 8,
#  236: 63,
#  237: 2,
#  238: 76,
#  239: 82,
#  240: 46,
#  241: 133,
#  242: 1,
#  243: 65,
#  244: 58,
#  245: 2,
#  246: 24,
#  247: 44,
#  248: 61,
#  249: 39,
#  250: 54,
#  251: 42,
#  252: 64,
#  253: 82,
#  254: 4,
#  255: 52,
#  256: 20,
#  257: 1,
#  258: 79,
#  259: 81,
#  260: 145,
#  261: 17,
#  262: 20,
#  263: 38,
#  264: 71,
#  265: 23,
#  266: 14,
#  267: 1,
#  268: 32,
#  269: 2,
#  270: 1,
#  271: 121,
#  272: 9,
#  273: 64,
#  274: 1,
#  275: 36,
#  276: 21,
#  277: 1,
#  278: 1,
#  279: 76,
#  280: 1,
#  281: 1,
#  282: 27,
#  283: 1,
#  284: 36,
#  285: 1,
#  286: 1,
#  287: 105,
#  288: 18,
#  289: 1,
#  290: 38,
#  291: 235,
#  292: 1,
#  293: 2,
#  294: 1,
#  295: 27,
#  296: 37,
#  297: 15,
#  298: 1,
#  299: 3,
#  300: 46,
#  301: 61,
#  302: 147,
#  303: 55,
#  304: 32,
#  305: 2,
#  306: 99,
#  307: 5,
#  308: 8,
#  309: 1,
#  310: 61,
#  311: 11,
#  312: 26,
#  313: 1,
#  314: 48,
#  315: 99,
#  316: 1,
#  317: 3,
#  318: 5,
#  319: 11,
#  320: 2,
#  321: 52,
#  322: 2,
#  323: 27,
#  324: 3,
#  325: 105,
#  326: 1033,
#  327: 61,
#  328: 18,
#  329: 170,
#  330: 17,
#  331: 29,
#  332: 10,
#  333: 1,
#  334: 57,
#  335: 1,
#  336: 27,
#  337: 82,
#  338: 72,
#  339: 59,
#  340: 224,
#  341: 24,
#  342: 1,
#  343: 30,
#  344: 5,
#  345: 95,
#  346: 139,
#  347: 4,
#  348: 1,
#  349: 1,
#  350: 25,
#  351: 28,
#  352: 16,
#  353: 85,
#  354: 99,
#  355: 12,
#  356: 121,
#  357: 92,
#  358: 45,
#  359: 3,
#  360: 12,
#  361: 84,
#  362: 2,
#  363: 105,
#  364: 1,
#  365: 18,
#  366: 25,
#  367: 6,
#  368: 5,
#  369: 44,
#  370: 2,
#  371: 5,
#  372: 7,
#  373: 3,
#  374: 13,
#  375: 50,
#  376: 59,
#  377: 66,
#  378: 1,
#  379: 1,
#  380: 54,
#  381: 34,
#  382: 1,
#  383: 159,
#  384: 80,
#  385: 69,
#  386: 18,
#  387: 3,
#  388: 46,
#  389: 1,
#  390: 111,
#  391: 12,
#  392: 54,
#  393: 1,
#  394: 39,
#  395: 1,
#  396: 75,
#  397: 5,
#  398: 1,
#  399: 7,
#  400: 1,
#  401: 1,
#  402: 1,
#  403: 274,
#  404: 2,
#  405: 47,
#  406: 4,
#  407: 91,
#  408: 7,
#  409: 84,
#  410: 32,
#  411: 66,
#  412: 1,
#  413: 3,
#  414: 6,
#  415: 122,
#  416: 1,
#  417: 7,
#  418: 3,
#  419: 32,
#  420: 1,
#  421: 47,
#  422: 3,
#  423: 25,
#  424: 20,
#  425: 1,
#  426: 2,
#  427: 1,
#  428: 1,
#  429: 26,
#  430: 2,
#  431: 56,
#  432: 1,
#  433: 1,
#  434: 105,
#  435: 96,
#  436: 88,
#  437: 1,
#  438: 60,
#  439: 107,
#  440: 1,
#  441: 3,
#  442: 20,
#  443: 74,
#  444: 4,
#  445: 24,
#  446: 50,
#  447: 22,
#  448: 6,
#  449: 1,
#  450: 8,
#  451: 1,
#  452: 36,
#  453: 32,
#  454: 171,
#  455: 58,
#  456: 13,
#  457: 37,
#  458: 47,
#  459: 29,
#  460: 52,
#  461: 55,
#  462: 32,
#  463: 1,
#  464: 50,
#  465: 83,
#  466: 85,
#  467: 73,
#  468: 70,
#  469: 2,
#  470: 21,
#  471: 1,
#  472: 2,
#  473: 88,
#  474: 2,
#  475: 40,
#  476: 2,
#  477: 3,
#  478: 1,
#  479: 120,
#  480: 5,
#  481: 7,
#  482: 115,
#  483: 1,
#  484: 25,
#  485: 17,
#  486: 65,
#  487: 1,
#  488: 98,
#  489: 2,
#  490: 6,
#  491: 1,
#  492: 1,
#  493: 3,
#  494: 35,
#  495: 1,
#  496: 100,
#  497: 4,
#  498: 4,
#  499: 8}

# %%
doc_l = kmeans_get_docs_with_idx(km_model, 7)

dframe.loc[dframe['identifier-uri'].isin(doc_l)]['contributor-department']
# Out:
# 261                           Marriage and Family Therapy
# 415                           Marriage and Family Therapy
# 580       Forest Resources and Environmental Conservation
# 685                                     Human Development
# 1851                                    Human Development
# 2079                                             Forestry
# 2274                                           Psychology
# 2484                                    Human Development
# 2589                                    Human Development
# 2629                                    Human Development
# 2727                                            Marketing
# 2954                               Landscape Architecture
# 3061                                    Human Development
# 3069                                    Human Development
# 3384                                    Human Development
# 4074                                    Human Development
# 4109                                    Human Development
# 4228                         Family and Child Development
# 4266                                    Human Development
# 4407                                    Human Development
# 4538                          Marriage and Family Therapy
# 4880                                    Human Development
# 4940                                    Human Development
# 4954                          Marriage and Family Therapy
# 5059                                    Human Development
# 5361                                    Human Development
# 5570                                    Human Development
# 5783                                    Human Development
# 6411                         Family and Child Development
# 6507                         Family and Child Development
# 8267                                    Human Development
# 9839                          Marriage and Family Therapy
# 10293                          Curriculum and Instruction
# 10745                                   Human Development
# 12003                         Marriage and Family Therapy
# 12711                        Family and Child Development
# 13233                                   Human Development
# 13245                                   Human Development
# 13581                                   Human Development
# 14624                                   Human Development
# 14835                                   Human Development
# 14837                                   Human Development
# 15874                                           Sociology
# 16747                         Marriage and Family Therapy
# 17418                              Landscape Architecture
# 17664                                   Human Development
# 17684                                   Human Development
# 17949           Marriage and Family Therapy Concentration
# 18180           Educational Leadership and Policy Studies
# 18904           Educational Leadership and Policy Studies
# 19104           Educational Leadership and Policy Studies
# 19295                               Teaching and Learning
# 19298           Educational Leadership and Policy Studies
# 19357           Educational Leadership and Policy Studies
# 19448           Educational Leadership and Policy Studies
# 19721           Educational Leadership and Policy Studies
# 19740                                   Human Development
# 19744           Educational Leadership and Policy Studies
# 19745                                   Human Development
# 19844                                   Human Development
# 19956           Educational Leadership and Policy Studies
# 20121                                   Human Development
# 20553                               Teaching and Learning
# 21359           Educational Leadership and Policy Studies
# 21486    Counselor Education and Student Personnel Serv...
# 21492                                   Human Development
# 21520           Educational Leadership and Policy Studies
# 21587                                   Human Development
# 21760           Educational Leadership and Policy Studies
# 22501                                   Human Development
# 22564                        Family and Child Development
# 22630                               Teaching and Learning
# 22705                               Teaching and Learning
# 22830       Adult Learning and Human Resource Development
# 23353                                   Human Development
# 25314                        Family and Child Development
# 25470                          Educational Administration
# 25984                          Educational Administration
# 26084                Agricultural and Extension Education
# 26311                        Family and Child Development
# 26397                                   Human Development
# 26884           Educational Leadership and Policy Studies
# 26943           Educational Leadership and Policy Studies
# 27279                                   Human Development
# 28069                               Engineering Education
# 28117           Educational Leadership and Policy Studies
# 28454           Educational Leadership and Policy Studies
# 28790                                 Counselor Education
# 29679           Educational Leadership and Policy Studies
# 29834                                 Counselor Education
# 30120                                   Human Development
# 30270                                   Human Development
# 30344                                   Human Development
# 30939                        Education, Community College
# Name: contributor-department, dtype: object

# %%
doc_l = kmeans_get_docs_with_idx(km_model, 6)

dframe.loc[dframe['identifier-uri'].isin(doc_l)]['contributor-department']
# Out:
# 374                                               Biology
# 564       Forest Resources and Environmental Conservation
# 670                  Crop and Soil Environmental Sciences
# 919       Forest Resources and Environmental Conservation
# 924                        Biological Systems Engineering
# 1416                            Environmental Engineering
# 1653                                         Horticulture
# 1931                 Crop and Soil Environmental Sciences
# 1970                 Crop and Soil Environmental Sciences
# 2210                 Crop and Soil Environmental Sciences
# 2246                 Crop and Soil Environmental Sciences
# 3133                                  Geological Sciences
# 3382                                         Horticulture
# 3618                                           Entomology
# 4207                                             Forestry
# 4364                                             Forestry
# 4546                 Crop and Soil Environmental Sciences
# 4551                                              Biology
# 4686                                             Forestry
# 4742                 Crop and Soil Environmental Sciences
# 4767                                             Forestry
# 5000                       Biological Systems Engineering
# 5035                                             Forestry
# 5785                                              Biology
# 5977                 Crop and Soil Environmental Sciences
# 6024                                         Horticulture
# 6172                 Crop and Soil Environmental Sciences
# 6264                 Crop and Soil Environmental Sciences
# 6460                            Environmental Engineering
# 6467                 Crop and Soil Environmental Sciences
# 7558                       Biological Systems Engineering
# 8022                 Crop and Soil Environmental Sciences
# 8889                            Environmental Engineering
# 10127              Environmental Sciences and Engineering
# 11642                Crop and Soil Environmental Sciences
# 11878                                            Agronomy
# 11901                                            Agronomy
# 12180                                            Agronomy
# 12798     Forest Resources and Environmental Conservation
# 12800                                        Horticulture
# 13071     Forest Resources and Environmental Conservation
# 13150     Forest Resources and Environmental Conservation
# 13376     Forest Resources and Environmental Conservation
# 14337                         Animal and Poultry Sciences
# 14353     Forest Resources and Environmental Conservation
# 15152     Forest Resources and Environmental Conservation
# 15709     Forest Resources and Environmental Conservation
# 16217                                 Biological Sciences
# 17117                         Food Science and Technology
# 17251                Crop and Soil Environmental Sciences
# 17667                Crop and Soil Environmental Sciences
# 17719                Crop and Soil Environmental Sciences
# 17733                      Biological Systems Engineering
# 17871                                 Biological Sciences
# 19244                                 Biological Sciences
# 23112                              Agricultural Economics
# 23221                Crop and Soil Environmental Sciences
# 25604                Crop and Soil Environmental Sciences
# 25778                Crop and Soil Environmental Sciences
# 25870                Crop and Soil Environmental Sciences
# 25891                                            Forestry
# 25957                                   Civil Engineering
# 26202                      Biological Systems Engineering
# 26496                Crop and Soil Environmental Sciences
# 27053                Crop and Soil Environmental Sciences
# 27141                      Biological Systems Engineering
# 30259                                        Horticulture
# 30403                                            Forestry
# 30469    Genetics, Bioinformatics, and Computational Bi...
# Name: contributor-department, dtype: object
